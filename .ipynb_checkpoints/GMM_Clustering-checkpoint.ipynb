# %%
using Distributions, StatsPlots, Random

# Set a random seed.
Random.seed!(3)

# Construct 30 data points for each cluster.
N = 100

# Parameters for each cluster, we assume that each cluster is Gaussian distributed in the example.
μs = [-3.5, 0.0]

# Construct the data points.
x = mapreduce(c -> rand(MvNormal([μs[c], μs[c]], 1.), N), hcat, 1:2)

# Visualization.
scatter(x[1,:], x[2,:], legend = false, title = "Synthetic Dataset")

# %%
using Turing, MCMCChains, ReverseDiff
using Memoization

Turing.setadbackend(:reversediff)
Turing.setrdcache(true)
# Out:
# true

# %%
@model GaussianMixtureModel(x) = begin
    
    D, N = size(x)

    # Draw the parameters for cluster 1.
    μ1 ~ Normal()
    
    # Draw the parameters for cluster 2.
    μ2 ~ Normal()
    
    μ = [μ1, μ2]
    
    for i in 1:N
        x[:,i] ~ MixtureModel(MvNormal, [([μ1,μ1], 1.0), ([μ2,μ2], 1.0)])
    end
end;

# %%
gmm_model = GaussianMixtureModel(x);
# gmm_sampler = Gibbs(PG(100, :k), HMC(0.05, 10, :μ1, :μ2))
chain = sample(gmm_model, NUTS(0.65), 1000)

# %%
plot(chain)

# %%
@model GaussianMixtureModel2(x) = begin
    
    D, N = size(x)

    # Draw the parameters for cluster 1.
    μ1 ~ Normal()
    
    # Draw the parameters for cluster 2.
    μ2 ~ Normal()
    
    μ = [μ1, μ2]
    
    # Uncomment the following lines to draw the weights for the K clusters 
    # from a Dirichlet distribution.
    
    # α = 1.0
    # w ~ Dirichlet(2, α)
    
    # Comment out this line if you instead want to draw the weights.
    w = [0.5, 0.5]
    
    # Draw assignments for each datum and generate it from a multivariate normal.
    k = Vector{Int}(undef, N)
    for i in 1:N
        k[i] ~ Categorical(w)
        x[:,i] ~ MvNormal([μ[k[i]], μ[k[i]]], 1.)
    end
    return k
end
# Out:
# DynamicPPL.ModelGen{var"###generator#608",(:x,),(),Tuple{}}(##generator#608, NamedTuple())

# %%
gmm_model = GaussianMixtureModel2(x);
gmm_sampler = Gibbs(PG(100, :k), HMC(0.05, 10, :μ1, :μ2))
# tchain = mapreduce(c -> sample(gmm_model, gmm_sampler, 100), chainscat, 1:3);
chain = sample(gmm_model, gmm_sampler, 100)
# Out:
# Sampling: 100%|█████████████████████████████████████████| Time: 0:01:20
# Object of type Chains, with data of type 100×63×1 Array{Float64,3}
#
# Iterations        = 1:100
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 100
# internals         = lp
# parameters        = k[1], k[2], k[3], k[4], k[5], k[6], k[7], k[8], k[9], k[10], k[11], k[12], k[13], k[14], k[15], k[16], k[17], k[18], k[19], k[20], k[21], k[22], k[23], k[24], k[25], k[26], k[27], k[28], k[29], k[30], k[31], k[32], k[33], k[34], k[35], k[36], k[37], k[38], k[39], k[40], k[41], k[42], k[43], k[44], k[45], k[46], k[47], k[48], k[49], k[50], k[51], k[52], k[53], k[54], k[55], k[56], k[57], k[58], k[59], k[60], μ1, μ2
#
# 2-element Array{ChainDataFrame,1}
#
# Summary Statistics
#   parameters     mean     std  naive_se     mcse       ess   r_hat
#   ──────────  ───────  ──────  ────────  ───────  ────────  ──────
#         k[1]   1.0800  0.2727    0.0273  missing   27.6152  1.0117
#        k[48]   1.9100  0.2876    0.0288  missing  100.1187  1.0009
#        k[49]   1.8700  0.3380    0.0338  missing   24.5454  1.0121
#        k[50]   1.8900  0.3145    0.0314  missing   77.0988  0.9991
#        k[51]   1.8200  0.3861    0.0386  missing   67.7957  1.0007
#        k[52]   1.9300  0.2564    0.0256  missing   69.8021  1.0287
#        k[53]   1.8300  0.3775    0.0378  missing   73.0771  1.0076
#        k[54]   1.7800  0.4163    0.0416  missing  114.0357  1.0109
#        k[55]   1.6700  0.4726    0.0473  missing  106.0220  1.0012
#        k[56]   1.8500  0.3589    0.0359  missing   43.2498  1.0288
#        k[57]   1.8900  0.3145    0.0314  missing  119.5382  0.9910
#        k[58]   1.8300  0.3775    0.0378  missing  157.1838  0.9907
#        k[59]   1.7000  0.4606    0.0461  missing  207.4423  0.9899
#        k[60]   1.6900  0.4648    0.0465  missing  109.9834  0.9904
#           μ1  -1.8744  0.1756    0.0176  missing   24.7769  0.9917
#           μ2  -1.3261  0.3521    0.0352  missing   29.1008  0.9906
#
# Quantiles
#   parameters     2.5%    25.0%    50.0%    75.0%    97.5%
#   ──────────  ───────  ───────  ───────  ───────  ───────
#         k[1]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[2]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[3]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[4]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[5]   1.0000   1.0000   1.0000   2.0000   2.0000
#         k[6]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[7]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[8]   1.0000   1.0000   1.0000   1.0000   2.0000
#         k[9]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[10]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[11]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[12]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[13]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[14]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[15]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[16]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[17]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[18]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[19]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[20]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[21]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[22]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[23]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[24]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[25]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[26]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[27]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[28]   1.0000   1.0000   1.0000   1.2500   2.0000
#        k[29]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[30]   1.0000   1.0000   1.0000   1.0000   2.0000
#        k[31]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[32]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[33]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[34]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[35]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[36]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[37]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[38]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[39]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[40]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[41]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[42]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[43]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[44]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[45]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[46]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[47]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[48]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[49]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[50]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[51]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[52]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[53]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[54]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[55]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[56]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[57]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[58]   1.0000   2.0000   2.0000   2.0000   2.0000
#        k[59]   1.0000   1.0000   2.0000   2.0000   2.0000
#        k[60]   1.0000   1.0000   2.0000   2.0000   2.0000
#           μ1  -2.1108  -1.9519  -1.8739  -1.7989  -1.6281
#           μ2  -2.1281  -1.4529  -1.3184  -1.1863  -0.5999

# %%
plot(chain[:k])
# Out:
# Object of type Chains, with data of type 100×60×1 Array{Float64,3}
#
# Iterations        = 1:100
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 100
